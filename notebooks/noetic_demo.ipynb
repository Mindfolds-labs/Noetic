# %% [markdown]
# # Noetic Demo
# Demonstração de pipeline TF, RIVE, export ONNX e API.

# %%
from noetic_pawp.data.tf_pipeline import create_nyuv2_dataset
from noetic_pawp.data.rive_tf import RIVEPreprocessor

# %%
print('Configure paths locais e execute os módulos conforme docs/noetic/*.md')
